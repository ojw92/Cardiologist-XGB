# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../Data/heart_2022_clean_stepwise0.1.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246022 entries, 0 to 246021
# Data columns (total 32 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   SleepHours                                          246022 non-null  int64
#  1   HeightInMeters                                      246022 non-null  float64
#  2   GeneralHealth                                       246022 non-null  int64
#  3   RemovedTeeth                                        246022 non-null  int64
#  4   AgeCategory                                         246022 non-null  int64
#  5   SmokerStatus_ord                                    246022 non-null  int64
#  6   AlcoholDrinkers                                     246022 non-null  int64
#  7   BlindOrVisionDifficulty                             246022 non-null  int64
# ...

# %%
# set predict and response variables
set_seed = 123
y = df['HadHeartAttack']
x = df.drop(columns=['HadHeartAttack'])

# train / test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=set_seed)

# %%
# create dataframe for training
train_df = pd.concat([x_train, y_train], axis=1)
train_df = train_df.loc[:, ~train_df.columns.str.contains('^Unnamed', regex=True)]
train_df.head()
# Out:
#        SleepHours  HeightInMeters  GeneralHealth  RemovedTeeth  AgeCategory  \
# 34098           7            1.65              4             1            4
# 68255           7            1.63              3             3           11
# 42301           7            1.75              4             1            5
# 4289            4            1.57              5             2           11
# 97983           7            1.52              3             1            5
#
#        SmokerStatus_ord  AlcoholDrinkers  BlindOrVisionDifficulty  ChestScan  \
# 34098                 2                1                        0          0
# 68255                 4                0                        0          1
# 42301                 1                1                        0          0
# 4289                  1                0                        0          1
# 97983                 1                1                        0          1
#
# ...

# %%
# create dataframe for testing
test_df = pd.concat([x_test, y_test], axis=1)
test_df = test_df.loc[:, ~test_df.columns.str.contains('^Unnamed', regex=True)]
test_df.head()
# Out:
#         SleepHours  HeightInMeters  GeneralHealth  RemovedTeeth  AgeCategory  \
# 60531            7            1.68              4             1            2
# 97119            7            1.88              3             2            6
# 188179           6            1.88              5             1            4
# 150458           8            1.78              5             1            5
# 112182           8            1.65              5             2            5
#
#         SmokerStatus_ord  AlcoholDrinkers  BlindOrVisionDifficulty  ChestScan  \
# 60531                  2                1                        0          1
# 97119                  4                1                        0          1
# 188179                 2                1                        0          0
# 150458                 1                1                        0          0
# 112182                 1                1                        0          0
#
# ...

# %%
# generate csv files
train_df.to_csv('../Data/train_df0.1.csv', index = False)
test_df.to_csv('../Data/test_df0.1.csv', index = False)
